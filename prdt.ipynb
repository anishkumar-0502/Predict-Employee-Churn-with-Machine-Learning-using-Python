# %% [markdown]
# <a href="https://colab.research.google.com/github/anishkumarak8686/Anish-OCR/blob/main/prdt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

hr_df=pd.read_csv('/content/sample_data/HR_comma_sep2.csv')

# %%
hr_df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department  salary  employee_id
# 0                          0      sales     low         1003
# 1                          0      sales  medium         1005
# 2                          0      sales  medium         1486
# 3                          0      sales     low         1038
# 4                          0      sales     low         1057
# ...                      ...        ...     ...          ...
# 14994                      0    support     low        87670
# 14995                      0    support     low        87673
# 14996                      0    support     low        87679
# 14997                      0    support     low        87681
# 14998                      0    support     low        87684
#
# [14999 rows x 11 columns]

# %%
#Numerical Analysis

# %%
hr_df.shape
# Out:
# (14999, 11)

# %%
hr_df.shape
# Out:
# (14999, 11)

# %%
hr_df.size
# Out:
# 164989

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
#  10  employee_id            14999 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.3+ MB

# %%
hr_df['Department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
hr_df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
#  10  employee_id            14999 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.3+ MB

# %%
hr_df[hr_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [satisfaction_level, last_evaluation, number_project, average_montly_hours, time_spend_company, Work_accident, left, promotion_last_5years, Department, salary, employee_id]
# Index: []

# %%
hr_df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# employee_id              0
# dtype: int64

# %%
hr_df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years   employee_id
# count           14999.000000  14999.000000
# mean                0.021268  45424.627575
# std                 0.144281  25915.900127
# min                 0.000000   1003.000000
# 25%                 0.000000  22872.500000
# 50%                 0.000000  45448.000000
# 75%                 0.000000  67480.500000
# max                 1.000000  99815.000000

# %%
hr_df.loc[hr_df['employee_id']==1340]
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 53                0.39             0.54               2                   132
#
#     time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 53                   3              0     1                      0    support
#
#    salary  employee_id
# 53    low         1340

# %%
# hr_df.drop(columns='employee_id',inplace=True)
hr_df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department  salary  employee_id
# 0                          0      sales     low         1003
# 1                          0      sales  medium         1005
# 2                          0      sales  medium         1486
# 3                          0      sales     low         1038
# 4                          0      sales     low         1057
# ...                      ...        ...     ...          ...
# 14994                      0    support     low        87670
# 14995                      0    support     low        87673
# 14996                      0    support     low        87679
# 14997                      0    support     low        87681
# 14998                      0    support     low        87684
#
# [14999 rows x 11 columns]

# %%
hr_df.groupby('Department').sum()
# Out:
#              satisfaction_level  last_evaluation  number_project  \
# Department
# IT                       758.46           879.55            4683
# RandD                    487.80           560.44            3033
# accounting               446.51           550.49            2934
# hr                       442.52           523.84            2701
# management               391.45           456.12            2432
# marketing                530.76           614.23            3164
# product_mng              558.91           644.71            3434
# sales                   2543.81          2938.23           15634
# support                 1378.19          1611.81            8479
# technical               1653.48          1961.39           10548
#
#              average_montly_hours  time_spend_company  Work_accident  left  \
# Department
# IT                         248119                4256            164   273
# RandD                      158030                2650            134   121
# accounting                 154292                2702             96   204
# hr                         146828                2480             89   215
# management                 126787                2711            103    91
# marketing                  171073                3063            138   203
# product_mng                180369                3135            132   198
# sales                      831773               14631            587  1014
# support                    447490                7563            345   555
# technical                  550793                9279            381   697
#
#              promotion_last_5years  employee_id
# Department
# IT                               3     56344929
# RandD                           27     32948168
# accounting                      14     34474313
# hr                              15     31664725
# management                      69     33597098
# marketing                       43     40715777
# product_mng                      0     44016858
# sales                          100    192072490
# support                         20     97874011
# technical                       28    117615620

# %%
hr_df.groupby('Department').mean()
# Out:
#              satisfaction_level  last_evaluation  number_project  \
# Department
# IT                     0.618142         0.716830        3.816626
# RandD                  0.619822         0.712122        3.853875
# accounting             0.582151         0.717718        3.825293
# hr                     0.598809         0.708850        3.654939
# management             0.621349         0.724000        3.860317
# marketing              0.618601         0.715886        3.687646
# product_mng            0.619634         0.714756        3.807095
# sales                  0.614447         0.709717        3.776329
# support                0.618300         0.723109        3.803948
# technical              0.607897         0.721099        3.877941
#
#              average_montly_hours  time_spend_company  Work_accident  \
# Department
# IT                     202.215974            3.468623       0.133659
# RandD                  200.800508            3.367217       0.170267
# accounting             201.162973            3.522816       0.125163
# hr                     198.684709            3.355886       0.120433
# management             201.249206            4.303175       0.163492
# marketing              199.385781            3.569930       0.160839
# product_mng            199.965632            3.475610       0.146341
# sales                  200.911353            3.534058       0.141787
# support                200.758188            3.393001       0.154778
# technical              202.497426            3.411397       0.140074
#
#                  left  promotion_last_5years   employee_id
# Department
# IT           0.222494               0.002445  45920.887531
# RandD        0.153748               0.034307  41865.524778
# accounting   0.265971               0.018253  44946.953064
# hr           0.290934               0.020298  42848.071719
# management   0.144444               0.109524  53328.726984
# marketing    0.236597               0.050117  47454.285548
# product_mng  0.219512               0.000000  48799.177384
# sales        0.244928               0.024155  46394.321256
# support      0.248991               0.008973  43909.381337
# technical    0.256250               0.010294  43241.036765

# %%
hr_df['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
#Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def plot_corr(df,size=10):
    
    corr=df.corr()
    fig,ax=plt.subplots(figsize=(size,size))
    ax.legend()
    cax=ax.matshow(corr)
    fig.colorbar(cax)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
    plt.yticks(range(len(corr.columns)), corr.columns)
    

plot_corr(hr_df)
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
with sns.color_palette('muted'):
    sns.countplot(x=hr_df['left'])

# %%
sns.pairplot(hr_df,hue='left')

# %%
#Data Preprocessing
Y = hr_df[['Department','salary']]

# %%
Y
# Out:
#       Department  salary
# 0          sales     low
# 1          sales  medium
# 2          sales  medium
# 3          sales     low
# 4          sales     low
# ...          ...     ...
# 14994    support     low
# 14995    support     low
# 14996    support     low
# 14997    support     low
# 14998    support     low
#
# [14999 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

hr_df['salary']=le.fit_transform(hr_df['salary'])

# %%
hr_df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department  salary  employee_id
# 0                          0      sales       1         1003
# 1                          0      sales       2         1005
# 2                          0      sales       2         1486
# 3                          0      sales       1         1038
# 4                          0      sales       1         1057
# ...                      ...        ...     ...          ...
# 14994                      0    support       1        87670
# 14995                      0    support       1        87673
# 14996                      0    support       1        87679
# 14997                      0    support       1        87681
# 14998                      0    support       1        87684
#
# [14999 rows x 11 columns]

# %%
hr_df['Department']=le.fit_transform(hr_df['Department'])

# %%
hr_df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years  Department  salary  employee_id
# 0                          0           7       1         1003
# 1                          0           7       2         1005
# 2                          0           7       2         1486
# 3                          0           7       1         1038
# 4                          0           7       1         1057
# ...                      ...         ...     ...          ...
# 14994                      0           8       1        87670
# 14995                      0           8       1        87673
# 14996                      0           8       1        87679
# 14997                      0           8       1        87681
# 14998                      0           8       1        87684
#
# [14999 rows x 11 columns]

# %%
X = hr_df.drop(['left'],axis=1)
y = hr_df.left

# %%
X
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                       157                   3              0
# 1                       262                   6              0
# 2                       272                   4              0
# 3                       223                   5              0
# 4                       159                   3              0
# ...                     ...                 ...            ...
# 14994                   151                   3              0
# 14995                   160                   3              0
# 14996                   143                   3              0
# 14997                   280                   4              0
# 14998                   158                   3              0
#
#        promotion_last_5years  Department  salary  employee_id
# 0                          0           7       1         1003
# 1                          0           7       2         1005
# 2                          0           7       2         1486
# 3                          0           7       1         1038
# 4                          0           7       1         1057
# ...                      ...         ...     ...          ...
# 14994                      0           8       1        87670
# 14995                      0           8       1        87673
# 14996                      0           8       1        87679
# 14997                      0           8       1        87681
# 14998                      0           8       1        87684
#
# [14999 rows x 10 columns]

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=89)
scores_dict = {}

# %%
# Standard Scaler
# Model Classification
# Decision Tree
from sklearn.metrics import accuracy_score, classification_report

# %%
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()

dt.fit(X_train,y_train)
prediction_dt = dt.predict(X_test)

accuracy_dt = accuracy_score(y_test,prediction_dt)*100

# %%
print('Accuracy score : ',accuracy_dt)
scores_dict['DecisionTreeClassifier'] = accuracy_dt
print(classification_report(y_test,prediction_dt))
# Out:
# Accuracy score :  97.51111111111112
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      3432
#            1       0.95      0.95      0.95      1068
#
#     accuracy                           0.98      4500
#    macro avg       0.96      0.97      0.97      4500
# weighted avg       0.98      0.98      0.98      4500

# %%
Catagory=['Employee will stay','Employee will Leave']

# %%
custom_dt=[[1,500,3,6,0,0.90,0.89,1,8,0]]

# %%
print(int(dt.predict(custom_dt)))
# Out:
# 1
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
Catagory[int(dt.predict(custom_dt))]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# 'Employee will Leave'

# %%
dt.feature_importances_
# Out:
# array([2.09344519e-01, 5.36396211e-02, 2.58015342e-02, 3.62371287e-02,
#        1.55387989e-01, 7.00120198e-04, 3.25935827e-04, 5.81720665e-03,
#        4.29638555e-03, 5.08449560e-01])

# %%
feature_importance=pd.DataFrame(dt.feature_importances_,index=X_train.columns,columns=['Importance']).sort_values('Importance',ascending=False)

# %%
feature_importance
# Out:
#                        Importance
# employee_id              0.508450
# satisfaction_level       0.209345
# time_spend_company       0.155388
# last_evaluation          0.053640
# average_montly_hours     0.036237
# number_project           0.025802
# Department               0.005817
# salary                   0.004296
# Work_accident            0.000700
# promotion_last_5years    0.000326

# %%
#KNN
# Data Processing of KNN
from sklearn.preprocessing import StandardScaler
print(list(hr_df.columns))
# Out:
# ['satisfaction_level', 'last_evaluation', 'number_project', 'average_montly_hours', 'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years', 'Department', 'salary', 'employee_id']

# %%
num_features = list(hr_df.columns)
for x in ['salary','Department','left']:
    num_features.remove(x)

sc = StandardScaler()

X_train_std=sc.fit_transform(X_train[num_features])
X_test_std=sc.transform(X_test[num_features])

# %%
from sklearn.neighbors import KNeighborsClassifier

k_range=range(1,26)
scores={}
scores_list=[]
bestk=0
h_score = 0

for i in range(1,26):
    clf = KNeighborsClassifier(n_neighbors=i).fit(X_train_std,y_train)
    pred = clf.predict(X_test_std)
    scores[i]=accuracy_score(y_test,pred)
    if scores[i]>h_score:
        h_score = scores[i]
        bestk = i
    scores_list.append(scores[i])
print('Best k is {} with score : {}'.format(bestk,h_score))
# Out:
# Best k is 2 with score : 0.9717777777777777

# %%
#  main model for KNN
knn=KNeighborsClassifier(n_neighbors=bestk)
knn.fit(X_train_std,y_train)
prediction_knn=knn.predict(X_test_std)
accuracy_knn=accuracy_score(y_test,prediction_knn)*100

# %%
print('Accuracy score : ',accuracy_knn)
scores_dict['KNeighborsClassifier'] = accuracy_score(y_test,prediction_knn)*100
print(classification_report(y_test,prediction_knn))
# Out:
# Accuracy score :  97.17777777777778
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      3432
#            1       0.97      0.91      0.94      1068
#
#     accuracy                           0.97      4500
#    macro avg       0.97      0.95      0.96      4500
# weighted avg       0.97      0.97      0.97      4500

# %%
plt.plot(k_range,scores_list)

# %%
# SVM
from sklearn.svm import SVC
model = SVC().fit(X_train_std,y_train)
pred = model.predict(X_test_std)
svc_accuracy = accuracy_score(y_test,pred)*100
print('Accuracy score : ',svc_accuracy)
scores_dict['SVC'] = svc_accuracy
print(classification_report(y_test,pred))
# Out:
# Accuracy score :  96.93333333333334
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      3432
#            1       0.95      0.92      0.93      1068
#
#     accuracy                           0.97      4500
#    macro avg       0.96      0.95      0.96      4500
# weighted avg       0.97      0.97      0.97      4500

# %%
from lightgbm import LGBMClassifier
model = LGBMClassifier(learning_rate=0.03,n_estimators=1000).fit(X_train_std,y_train)
pred = model.predict(X_test_std)
LGBM_accuracy = accuracy_score(y_test,pred)*100
print('Accuracy score : ',LGBM_accuracy)
scores_dict['LGBMClassifier'] = LGBM_accuracy
# Out:
# Accuracy score :  98.73333333333333

# %%
algo_name = list(scores_dict.keys())
accuracy_list = list(scores_dict.values())

sns.set(rc={'figure.figsize':(12.4,6.5)})
with sns.color_palette('muted'):
    sns.barplot(x=algo_name,y=accuracy_list)
